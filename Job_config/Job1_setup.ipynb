# %%
resources:
  jobs:
    Setup_DQ:
      name: Setup_DQ
      tasks:
        - task_key: init
          notebook_task:
            notebook_path: config/00_setup_framework
            source: GIT
      git_source:
        git_url: https://github.com/CAF-I-D/dp_datagovernance-data_quality.git
        git_provider: gitHub
        git_branch: main
      queue:
        enabled: true
      parameters:
        - name: catalog_name
          default: sap_databricks_sdg
        - name: schema_name
          default: framework_dq
      environments:
        - environment_key: Setup_environment
          spec:
            environment_version: "1"
      performance_target: PERFORMANCE_OPTIMIZED
